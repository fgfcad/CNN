# %%
import os
import shutil
import zipfile
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
from tensorflow.keras.preprocessing import image
from random import sample
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
# Descomprime la base de datos

local_zip = "C:/Users/ferga/Documents/Python/hojas/WeedCountImages_v1.zip"

zip_ref = zipfile.ZipFile(local_zip, 'r')

zip_ref.extractall("C:/Users/ferga/Documents/Python/hojas")
zip_ref.close()

# %%
# Cuenta el número de imágenes que hay por cada categoría

imag_1_hoja = 0
imag_2_hojas = 0
imag_3_hojas = 0
imag_4_hojas = 0
imag_5_hojas = 0
imag_6_hojas = 0
imag_7_hojas = 0
imag_8_hojas = 0
imag_9_hojas = 0
dir1 = "C:/Users/ferga/Documents/Python/hojas/1"
dir2 = "C:/Users/ferga/Documents/Python/hojas/2"
dir3 = "C:/Users/ferga/Documents/Python/hojas/3"
dir4 = "C:/Users/ferga/Documents/Python/hojas/4"
dir5 = "C:/Users/ferga/Documents/Python/hojas/5"
dir6 = "C:/Users/ferga/Documents/Python/hojas/6"
dir7 = "C:/Users/ferga/Documents/Python/hojas/7"
dir8 = "C:/Users/ferga/Documents/Python/hojas/8"
dir9 = "C:/Users/ferga/Documents/Python/hojas/9+"
for path in os.listdir(dir1):
    if os.path.isfile(os.path.join(dir1, path)):
        imag_1_hoja += 1
for path in os.listdir(dir2):
    if os.path.isfile(os.path.join(dir2, path)):
        imag_2_hojas += 1
for path in os.listdir(dir3):
    if os.path.isfile(os.path.join(dir3, path)):
        imag_3_hojas += 1
for path in os.listdir(dir4):
    if os.path.isfile(os.path.join(dir4, path)):
        imag_4_hojas += 1
for path in os.listdir(dir5):
    if os.path.isfile(os.path.join(dir5, path)):
        imag_5_hojas += 1
for path in os.listdir(dir6):
    if os.path.isfile(os.path.join(dir6, path)):
        imag_6_hojas += 1
for path in os.listdir(dir7):
    if os.path.isfile(os.path.join(dir7, path)):
        imag_7_hojas += 1
for path in os.listdir(dir8):
    if os.path.isfile(os.path.join(dir8, path)):
        imag_8_hojas += 1
for path in os.listdir(dir9):
    if os.path.isfile(os.path.join(dir9, path)):
        imag_9_hojas += 1
print('Imagenes de 1 hoja: '+ str(imag_1_hoja))
print('Imagenes de 2 hojas: '+ str(imag_2_hojas))
print('Imagenes de 3 hojas: '+ str(imag_3_hojas))
print('Imagenes de 4 hojas: '+ str(imag_4_hojas))
print('Imagenes de 5 hojas: '+ str(imag_5_hojas))
print('Imagenes de 6 hojas: '+ str(imag_6_hojas))
print('Imagenes de 7 hojas: '+ str(imag_7_hojas))
print('Imagenes de 8 hojas: '+ str(imag_8_hojas))
print('Imagenes de 9 hojas: '+ str(imag_9_hojas))
print('Total: ', imag_1_hoja+imag_2_hojas+imag_3_hojas+imag_4_hojas+imag_5_hojas+imag_6_hojas+imag_7_hojas+imag_8_hojas+imag_9_hojas)
# Out:
# Imagenes de 1 hoja: 908
# Imagenes de 2 hojas: 3292
# Imagenes de 3 hojas: 940
# Imagenes de 4 hojas: 2082
# Imagenes de 5 hojas: 601
# Imagenes de 6 hojas: 650
# Imagenes de 7 hojas: 169
# Imagenes de 8 hojas: 160
# Imagenes de 9 hojas: 570
# Total:  9372

# %%
#Cuenta cuantas imágenes servirán para train, para validation y para test, en este caso se ha seguido el criterio 80%-10%-10% respectivamente.

n_imag_train_1 = round(imag_1_hoja*0.8)
n_imag_validation_1 = imag_1_hoja//10
n_imag_test_1 = imag_1_hoja-n_imag_train_1-n_imag_validation_1
print('1 hoja: Train=' + str(n_imag_train_1) + ' Validation=' + str(n_imag_validation_1) + ' Test=' + str(n_imag_test_1))
n_imag_train_2 = round(imag_2_hojas*0.8)
n_imag_validation_2 = imag_2_hojas//10
n_imag_test_2 = imag_2_hojas-n_imag_train_2-n_imag_validation_2
print('2 hojas: Train=' + str(n_imag_train_2) + ' Validation=' + str(n_imag_validation_2) + ' Test=' + str(n_imag_test_2))
n_imag_train_3 = round(imag_3_hojas*0.8)
n_imag_validation_3 = imag_3_hojas//10
n_imag_test_3 = imag_3_hojas-n_imag_train_3-n_imag_validation_3
print('3 hojas: Train=' + str(n_imag_train_3) + ' Validation=' + str(n_imag_validation_3) + ' Test=' + str(n_imag_test_3))
n_imag_train_4 = round(imag_4_hojas*0.8)
n_imag_validation_4 = imag_4_hojas//10
n_imag_test_4 = imag_4_hojas-n_imag_train_4-n_imag_validation_4
print('4 hojas: Train=' + str(n_imag_train_4) + ' Validation=' + str(n_imag_validation_4) + ' Test=' + str(n_imag_test_4))
n_imag_train_5 = round(imag_5_hojas*0.8)
n_imag_validation_5 = imag_5_hojas//10
n_imag_test_5 = imag_5_hojas-n_imag_train_5-n_imag_validation_5
print('5 hojas: Train=' + str(n_imag_train_5) + ' Validation=' + str(n_imag_validation_5) + ' Test=' + str(n_imag_test_5))
n_imag_train_6 = round(imag_6_hojas*0.8)
n_imag_validation_6 = imag_6_hojas//10
n_imag_test_6 = imag_6_hojas-n_imag_train_6-n_imag_validation_6
print('6 hojas: Train=' + str(n_imag_train_6) + ' Validation=' + str(n_imag_validation_6) + ' Test=' + str(n_imag_test_6))
n_imag_train_7 = round(imag_7_hojas*0.8)
n_imag_validation_7 = imag_7_hojas//10
n_imag_test_7 = imag_7_hojas-n_imag_train_7-n_imag_validation_7
print('7 hojas: Train=' + str(n_imag_train_7) + ' Validation=' + str(n_imag_validation_7) + ' Test=' + str(n_imag_test_7))
n_imag_train_8 = round(imag_8_hojas*0.8)
n_imag_validation_8 = imag_8_hojas//10
n_imag_test_8 = imag_8_hojas-n_imag_train_8-n_imag_validation_8
print('8 hojas: Train=' + str(n_imag_train_8) + ' Validation=' + str(n_imag_validation_8) + ' Test=' + str(n_imag_test_8))
n_imag_train_9 = round(imag_9_hojas*0.8)
n_imag_validation_9 = imag_9_hojas//10
n_imag_test_9 = imag_9_hojas-n_imag_train_9-n_imag_validation_9
print('9 hojas: Train=' + str(n_imag_train_9) + ' Validation=' + str(n_imag_validation_9) + ' Test=' + str(n_imag_test_9))
# Out:
# 1 hoja: Train=726 Validation=90 Test=92
# 2 hojas: Train=2634 Validation=329 Test=329
# 3 hojas: Train=752 Validation=94 Test=94
# 4 hojas: Train=1666 Validation=208 Test=208
# 5 hojas: Train=481 Validation=60 Test=60
# 6 hojas: Train=520 Validation=65 Test=65
# 7 hojas: Train=135 Validation=16 Test=18
# 8 hojas: Train=128 Validation=16 Test=16
# 9 hojas: Train=456 Validation=57 Test=57

# %%
#Asignamos cada ruta a variables que luego serán necesarias.

base_dir = "C:/Users/ferga/Documents/Python/hojas"

train_dir =      os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')
test_dir =       os.path.join(base_dir, 'test')

## Directorio con las imagenes de train
# 1 hoja.
train_weed1_dir = os.path.join(train_dir, '1')
# 2 hojas.
train_weed2_dir = os.path.join(train_dir, '2')
# 3 hojas.
train_weed3_dir = os.path.join(train_dir, '3')
# 4 hojas.
train_weed4_dir = os.path.join(train_dir, '4')
# 5 hojas.
train_weed5_dir = os.path.join(train_dir, '5')
# 6 hojas.
train_weed6_dir = os.path.join(train_dir, '6')
# 7 hojas.
train_weed7_dir = os.path.join(train_dir, '7')
# 8 hojas.
train_weed8_dir = os.path.join(train_dir, '8')
# 9 hojas o más.
train_weed9plus_dir = os.path.join(train_dir, '9+')

## Directorio con las imagenes de validation
# 1 hoja
validation_weed1_dir = os.path.join(validation_dir, '1')
# 2 hojas
validation_weed2_dir = os.path.join(validation_dir, '2')
# 3 hojas
validation_weed3_dir = os.path.join(validation_dir, '3')
# 4 hojas
validation_weed4_dir = os.path.join(validation_dir, '4')
# 5 hojas
validation_weed5_dir = os.path.join(validation_dir, '5')
# 6 hojas
validation_weed6_dir = os.path.join(validation_dir, '6')
# 7 hojas
validation_weed7_dir = os.path.join(validation_dir, '7')
# 8 hojas
validation_weed8_dir = os.path.join(validation_dir, '8')
# 9 hojas o más
validation_weed9plus_dir = os.path.join(validation_dir, '9+')

## Directorio con las imagenes de test
# 1 hoja
test_weed1_dir = os.path.join(test_dir,'1')
# 2 hojas
test_weed2_dir = os.path.join(test_dir,'2')
# 3 hojas
test_weed3_dir = os.path.join(test_dir,'3')
# 4 hojas
test_weed4_dir = os.path.join(test_dir,'4')
# 5 hojas
test_weed5_dir = os.path.join(test_dir,'5')
# 6 hojas
test_weed6_dir = os.path.join(test_dir,'6')
# 7 hojas
test_weed7_dir = os.path.join(test_dir,'7')
# 8 hojas
test_weed8_dir = os.path.join(test_dir,'8')
# 9 hojas o más
test_weed9plus_dir = os.path.join(test_dir,'9+')

# %%
# Ordena cada foto en su respectiva carpeta de train, test o validation

# 1 hoja
contenido_1 = os.listdir(dir1)
contenido_1_random = sample(contenido_1, len(contenido_1))
for i in range(len(contenido_1_random)):
    if i < n_imag_train_1:
        shutil.copy(os.path.join(dir1, contenido_1_random[i]), train_weed1_dir)
    elif i >= n_imag_train_1 and i < n_imag_train_1+n_imag_validation_1:
        shutil.copy(os.path.join(dir1, contenido_1_random[i]), validation_weed1_dir)
    else:
        shutil.copy(os.path.join(dir1, contenido_1_random[i]), test_weed1_dir)
# 2 hojas
contenido_2 = os.listdir(dir2)
contenido_2_random = sample(contenido_2, len(contenido_2))
for i in range(len(contenido_2_random)):
    if i < n_imag_train_2:
        shutil.copy(os.path.join(dir2, contenido_2_random[i]), train_weed2_dir)
    elif i >= n_imag_train_2 and i < n_imag_train_2+n_imag_validation_2:
        shutil.copy(os.path.join(dir2, contenido_2_random[i]), validation_weed2_dir)
    else:
        shutil.copy(os.path.join(dir2, contenido_2_random[i]), test_weed2_dir)
# 3 hojas
contenido_3 = os.listdir(dir3)
contenido_3_random = sample(contenido_3, len(contenido_3))
for i in range(len(contenido_3_random)):
    if i < n_imag_train_3:
        shutil.copy(os.path.join(dir3, contenido_3_random[i]), train_weed3_dir)
    elif i >= n_imag_train_3 and i < n_imag_train_3+n_imag_validation_3:
        shutil.copy(os.path.join(dir3, contenido_3_random[i]), validation_weed3_dir)
    else:
        shutil.copy(os.path.join(dir3, contenido_3_random[i]), test_weed3_dir)
# 4 hojas
contenido_4 = os.listdir(dir4)
contenido_4_random = sample(contenido_4, len(contenido_4))
for i in range(len(contenido_4_random)):
    if i < n_imag_train_4:
        shutil.copy(os.path.join(dir4, contenido_4_random[i]), train_weed4_dir)
    elif i >= n_imag_train_4 and i < n_imag_train_4+n_imag_validation_4:
        shutil.copy(os.path.join(dir4, contenido_4_random[i]), validation_weed4_dir)
    else:
        shutil.copy(os.path.join(dir4, contenido_4_random[i]), test_weed4_dir)
# 5 hojas
contenido_5 = os.listdir(dir5)
contenido_5_random = sample(contenido_5, len(contenido_5))
for i in range(len(contenido_5_random)):
    if i < n_imag_train_5:
        shutil.copy(os.path.join(dir5, contenido_5_random[i]), train_weed5_dir)
    elif i >= n_imag_train_5 and i < n_imag_train_5+n_imag_validation_5:
        shutil.copy(os.path.join(dir5, contenido_5_random[i]), validation_weed5_dir)
    else:
        shutil.copy(os.path.join(dir5, contenido_5_random[i]), test_weed5_dir)
# 6 hojas
contenido_6 = os.listdir(dir6)
contenido_6_random = sample(contenido_6, len(contenido_6))
for i in range(len(contenido_6_random)):
    if i < n_imag_train_6:
        shutil.copy(os.path.join(dir6, contenido_6_random[i]), train_weed6_dir)
    elif i >= n_imag_train_6 and i < n_imag_train_6+n_imag_validation_6:
        shutil.copy(os.path.join(dir6, contenido_6_random[i]), validation_weed6_dir)
    else:
        shutil.copy(os.path.join(dir6, contenido_6_random[i]), test_weed6_dir)
# 7 hojas
contenido_7 = os.listdir(dir7)
contenido_7_random = sample(contenido_7, len(contenido_7))
for i in range(len(contenido_7_random)):
    if i < n_imag_train_7:
        shutil.copy(os.path.join(dir7, contenido_7_random[i]), train_weed7_dir)
    elif i >= n_imag_train_7 and i < n_imag_train_7+n_imag_validation_7:
        shutil.copy(os.path.join(dir7, contenido_7_random[i]), validation_weed7_dir)
    else:
        shutil.copy(os.path.join(dir7, contenido_7_random[i]), test_weed7_dir)
# 8 hojas
contenido_8 = os.listdir(dir8)
contenido_8_random = sample(contenido_8, len(contenido_8))
for i in range(len(contenido_8_random)):
    if i < n_imag_train_8:
        shutil.copy(os.path.join(dir8, contenido_8_random[i]), train_weed8_dir)
    elif i >= n_imag_train_8 and i < n_imag_train_8+n_imag_validation_8:
        shutil.copy(os.path.join(dir8, contenido_8_random[i]), validation_weed8_dir)
    else:
        shutil.copy(os.path.join(dir8, contenido_8_random[i]), test_weed8_dir)
# 9 hojas
contenido_9 = os.listdir(dir9)
contenido_9_random = sample(contenido_9, len(contenido_9))
for i in range(len(contenido_9_random)):
    if i < n_imag_train_9:
        shutil.copy(os.path.join(dir9, contenido_9_random[i]), train_weed9plus_dir)
    elif i >= n_imag_train_9 and i < n_imag_train_9+n_imag_validation_9:
        shutil.copy(os.path.join(dir9, contenido_9_random[i]), validation_weed9plus_dir)
    else:
        shutil.copy(os.path.join(dir9, contenido_9_random[i]), test_weed9plus_dir)

# %%
# Pequeña comprobación de que las fotos están bien ordenadas

#Train
train_weed1_fnames = os.listdir( train_weed1_dir )
print(train_weed1_fnames[:5])
train_weed2_fnames = os.listdir( train_weed2_dir )
print(train_weed2_fnames[:5])
train_weed3_fnames = os.listdir( train_weed3_dir )
print(train_weed3_fnames[:5])
train_weed4_fnames = os.listdir( train_weed4_dir )
print(train_weed4_fnames[:5])
train_weed5_fnames = os.listdir( train_weed5_dir )
print(train_weed5_fnames[:5])
train_weed6_fnames = os.listdir( train_weed6_dir )
print(train_weed6_fnames[:5])
train_weed7_fnames = os.listdir( train_weed7_dir )
print(train_weed7_fnames[:5])
train_weed8_fnames = os.listdir( train_weed8_dir )
print(train_weed8_fnames[:5])
train_weed9plus_fnames = os.listdir( train_weed9plus_dir )
print(train_weed9plus_fnames[:5])

#Validation

#Test
# Out:
# ['0.png', '10.png', '100.png', '101.png', '102.png']
# ['0.png', '1.png', '10.png', '100.png', '1000.png']
# ['0.png', '10.png', '100.png', '101.png', '102.png']
# ['0.png', '1.png', '10.png', '100.png', '1000.png']
# ['0.png', '1.png', '100.png', '101.png', '102.png']
# ['0.png', '1.png', '10.png', '100.png', '101.png']
# ['0.png', '1.png', '10.png', '100.png', '102.png']
# ['0.png', '1.png', '10.png', '100.png', '101.png']
# ['1.png', '10.png', '100.png', '102.png', '103.png']

# %%
#Comprueba el numero de fotos que hay en cada directorio para verificar que se ha realizado el reparto correctamente

print('total training weed1 images :', len(os.listdir(train_weed1_dir ) ))
print('total training weed2 images :', len(os.listdir(train_weed2_dir ) ))
print('total training weed3 images :', len(os.listdir(train_weed3_dir ) ))
print('total training weed4 images :', len(os.listdir(train_weed4_dir ) ))
print('total training weed5 images :', len(os.listdir(train_weed5_dir ) ))
print('total training weed6 images :', len(os.listdir(train_weed6_dir ) ))
print('total training weed7 images :', len(os.listdir(train_weed7_dir ) ))
print('total training weed8 images :', len(os.listdir(train_weed8_dir ) ))
print('total training weed9plus images :', len(os.listdir(train_weed9plus_dir ) ))

print('total validation weed1 images :', len(os.listdir( validation_weed1_dir ) ))
print('total validation weed2 images :', len(os.listdir( validation_weed2_dir ) ))
print('total validation weed3 images :', len(os.listdir( validation_weed3_dir ) ))
print('total validation weed4 images :', len(os.listdir( validation_weed4_dir ) ))
print('total validation weed5 images :', len(os.listdir( validation_weed5_dir ) ))
print('total validation weed6 images :', len(os.listdir( validation_weed6_dir ) ))
print('total validation weed7 images :', len(os.listdir( validation_weed7_dir ) ))
print('total validation weed8 images :', len(os.listdir( validation_weed8_dir ) ))
print('total validation weed9plus images :', len(os.listdir( validation_weed9plus_dir ) ))

print('total test weed1 images :', len(os.listdir( test_weed1_dir ) ))
print('total test weed2 images :', len(os.listdir( test_weed2_dir ) ))
print('total test weed3 images :', len(os.listdir( test_weed3_dir ) ))
print('total test weed4 images :', len(os.listdir( test_weed4_dir ) ))
print('total test weed5 images :', len(os.listdir( test_weed5_dir ) ))
print('total test weed6 images :', len(os.listdir( test_weed6_dir ) ))
print('total test weed7 images :', len(os.listdir( test_weed7_dir ) ))
print('total test weed8 images :', len(os.listdir( test_weed8_dir ) ))
print('total test weed9plus images :', len(os.listdir( test_weed9plus_dir ) ))
# Out:
# total training weed1 images : 726
# total training weed2 images : 2634
# total training weed3 images : 752
# total training weed4 images : 1666
# total training weed5 images : 481
# total training weed6 images : 520
# total training weed7 images : 135
# total training weed8 images : 128
# total training weed9plus images : 456
# total validation weed1 images : 90
# total validation weed2 images : 329
# total validation weed3 images : 94
# total validation weed4 images : 208
# total validation weed5 images : 60
# total validation weed6 images : 65
# total validation weed7 images : 16
# total validation weed8 images : 16
# total validation weed9plus images : 57
# total test weed1 images : 92
# total test weed2 images : 329
# total test weed3 images : 94
# total test weed4 images : 208
# total test weed5 images : 60
# total test weed6 images : 65
# total test weed7 images : 18
# total test weed8 images : 16
# total test weed9plus images : 57

# %%
# Representa un ejemplo de las imágenes que se van a tomar para resolver el problema. En este caso se representarán las de dos hojas

# presentaremos images en una configuración de 4x4
nrows = 4
ncols = 4

pic_index = 0 # Índice para iterar sobre las imagenes

fig = plt.gcf()
fig.set_size_inches(ncols*4, nrows*4)

pic_index+=8

next_weed_pix = [os.path.join(train_weed2_dir, fname) 
                for fname in train_weed2_fnames[ pic_index-8:pic_index] 
               ]

for i, img_path in enumerate(next_weed_pix):
  sp = plt.subplot(nrows, ncols, i + 1)
  img = mpimg.imread(img_path)
  plt.imshow(img)
  
plt.show()

# %%
#Creación de la CNN

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32,(3,3), activation='relu', input_shape=(150,150,3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64,(3,3), activation='relu' ),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(9, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 5, 5, 256)         590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               262400
# _________________________________________________________________
# dense_1 (Dense)              (None, 9)                 2313
# =================================================================
# Total params: 1,243,209
# Trainable params: 1,243,209
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer= 'sgd',
              metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(
      rescale=1.0/255.,
      rotation_range=60,
      horizontal_flip=True,
      vertical_flip=True,
      brightness_range=[0.5,1.5],
      fill_mode='nearest'
      )
validation_datagen  = ImageDataGenerator( rescale = 1.0/255. )
test_datagen  = ImageDataGenerator( rescale = 1.0/255. )

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    target_size=(150, 150))     

validation_generator =  validation_datagen.flow_from_directory(validation_dir,
                                                         batch_size=32,
                                                         class_mode  = 'categorical',
                                                         target_size = (150, 150))


test_generator =  test_datagen.flow_from_directory(test_dir,
                                                         batch_size=32,
                                                         class_mode  = 'categorical',
                                                         target_size = (150, 150))
# Out:
# Found 7498 images belonging to 9 classes.
# Found 935 images belonging to 9 classes.
# Found 939 images belonging to 9 classes.

# %%
batch_size = 64
steps_per_epoch = train_generator.n // batch_size
validation_steps = validation_generator.n // batch_size

print (steps_per_epoch)
print (validation_steps)
# Out:
# 117
# 14

# %%
history = model.fit(
    train_generator, 
    steps_per_epoch= steps_per_epoch,
    epochs=150,
    validation_data=validation_generator,
    validation_steps= validation_steps,
    verbose=2)
# Out:
# Epoch 1/150
# 117/117 - 61s - loss: 1.8962 - accuracy: 0.3480 - val_loss: 1.8368 - val_accuracy: 0.3259
# Epoch 2/150
# 117/117 - 39s - loss: 1.8299 - accuracy: 0.3475 - val_loss: 1.8233 - val_accuracy: 0.3527
# Epoch 3/150
# 117/117 - 35s - loss: 1.8263 - accuracy: 0.3413 - val_loss: 1.7696 - val_accuracy: 0.3862
# Epoch 4/150
# 117/117 - 39s - loss: 1.8147 - accuracy: 0.3523 - val_loss: 1.7793 - val_accuracy: 0.3795
# Epoch 5/150
# 117/117 - 35s - loss: 1.8033 - accuracy: 0.3568 - val_loss: 1.7985 - val_accuracy: 0.3504
# Epoch 6/150
# 117/117 - 33s - loss: 1.7913 - accuracy: 0.3600 - val_loss: 1.8142 - val_accuracy: 0.3750
# Epoch 7/150
# 117/117 - 32s - loss: 1.7714 - accuracy: 0.3694 - val_loss: 1.7021 - val_accuracy: 0.3996
# Epoch 8/150
# 117/117 - 33s - loss: 1.7460 - accuracy: 0.3643 - val_loss: 1.6891 - val_accuracy: 0.3817
# Epoch 9/150
# 117/117 - 33s - loss: 1.7210 - accuracy: 0.3834 - val_loss: 1.7367 - val_accuracy: 0.3795
# Epoch 10/150
# 117/117 - 32s - loss: 1.6955 - accuracy: 0.3961 - val_loss: 1.7276 - val_accuracy: 0.3862
# Epoch 11/150
# 117/117 - 32s - loss: 1.6973 - accuracy: 0.3889 - val_loss: 1.6754 - val_accuracy: 0.4420
# Epoch 12/150
# 117/117 - 32s - loss: 1.6789 - accuracy: 0.3958 - val_loss: 1.6827 - val_accuracy: 0.3817
# Epoch 13/150
# 117/117 - 32s - loss: 1.6701 - accuracy: 0.3998 - val_loss: 1.6988 - val_accuracy: 0.3616
# Epoch 14/150
# 117/117 - 32s - loss: 1.6739 - accuracy: 0.4020 - val_loss: 1.6525 - val_accuracy: 0.3973
# Epoch 15/150
# 117/117 - 32s - loss: 1.6370 - accuracy: 0.4199 - val_loss: 1.6168 - val_accuracy: 0.4062
# Epoch 16/150
# 117/117 - 32s - loss: 1.6236 - accuracy: 0.4188 - val_loss: 1.6672 - val_accuracy: 0.3862
# Epoch 17/150
# 117/117 - 32s - loss: 1.6285 - accuracy: 0.4196 - val_loss: 1.7914 - val_accuracy: 0.2902
# Epoch 18/150
# 117/117 - 32s - loss: 1.5950 - accuracy: 0.4359 - val_loss: 1.5733 - val_accuracy: 0.4129
# Epoch 19/150
# 117/117 - 32s - loss: 1.5892 - accuracy: 0.4303 - val_loss: 1.6194 - val_accuracy: 0.3906
# Epoch 20/150
# 117/117 - 33s - loss: 1.5686 - accuracy: 0.4374 - val_loss: 1.5965 - val_accuracy: 0.4688
# Epoch 21/150
# 117/117 - 33s - loss: 1.5674 - accuracy: 0.4423 - val_loss: 1.5624 - val_accuracy: 0.4509
# Epoch 22/150
# 117/117 - 33s - loss: 1.5515 - accuracy: 0.4503 - val_loss: 1.5301 - val_accuracy: 0.4487
# Epoch 23/150
# 117/117 - 32s - loss: 1.5248 - accuracy: 0.4653 - val_loss: 1.4929 - val_accuracy: 0.4732
# Epoch 24/150
# 117/117 - 33s - loss: 1.5194 - accuracy: 0.4696 - val_loss: 1.5185 - val_accuracy: 0.4866
# Epoch 25/150
# 117/117 - 40s - loss: 1.5093 - accuracy: 0.4645 - val_loss: 1.4291 - val_accuracy: 0.5089
# Epoch 26/150
# 117/117 - 45s - loss: 1.4841 - accuracy: 0.4818 - val_loss: 1.5248 - val_accuracy: 0.4375
# Epoch 27/150
# 117/117 - 40s - loss: 1.5093 - accuracy: 0.4701 - val_loss: 1.4450 - val_accuracy: 0.4732
# Epoch 28/150
# 117/117 - 36s - loss: 1.4674 - accuracy: 0.4761 - val_loss: 1.4186 - val_accuracy: 0.5112
# Epoch 29/150
# 117/117 - 37s - loss: 1.4614 - accuracy: 0.4861 - val_loss: 1.4123 - val_accuracy: 0.5156
# Epoch 30/150
# 117/117 - 38s - loss: 1.4602 - accuracy: 0.4842 - val_loss: 1.5208 - val_accuracy: 0.4442
# Epoch 31/150
# 117/117 - 36s - loss: 1.4490 - accuracy: 0.4888 - val_loss: 1.3620 - val_accuracy: 0.4866
# Epoch 32/150
# 117/117 - 36s - loss: 1.4187 - accuracy: 0.4970 - val_loss: 1.3913 - val_accuracy: 0.4777
# Epoch 33/150
# 117/117 - 38s - loss: 1.4013 - accuracy: 0.5003 - val_loss: 1.3472 - val_accuracy: 0.5067
# Epoch 34/150
# 117/117 - 35s - loss: 1.4213 - accuracy: 0.5056 - val_loss: 1.4482 - val_accuracy: 0.4866
# Epoch 35/150
# 117/117 - 35s - loss: 1.3879 - accuracy: 0.5118 - val_loss: 1.3850 - val_accuracy: 0.5223
# Epoch 36/150
# 117/117 - 36s - loss: 1.3991 - accuracy: 0.5045 - val_loss: 1.4031 - val_accuracy: 0.5022
# Epoch 37/150
# 117/117 - 32s - loss: 1.3897 - accuracy: 0.5132 - val_loss: 1.3882 - val_accuracy: 0.4955
# Epoch 38/150
# 117/117 - 31s - loss: 1.3557 - accuracy: 0.5134 - val_loss: 1.2784 - val_accuracy: 0.5179
# Epoch 39/150
# 117/117 - 32s - loss: 1.3393 - accuracy: 0.5243 - val_loss: 1.4403 - val_accuracy: 0.4643
# Epoch 40/150
# 117/117 - 32s - loss: 1.3771 - accuracy: 0.5088 - val_loss: 1.3219 - val_accuracy: 0.5179
# Epoch 41/150
# 117/117 - 30s - loss: 1.3370 - accuracy: 0.5304 - val_loss: 1.4995 - val_accuracy: 0.4531
# Epoch 42/150
# 117/117 - 31s - loss: 1.3457 - accuracy: 0.5280 - val_loss: 1.3637 - val_accuracy: 0.5000
# Epoch 43/150
# 117/117 - 31s - loss: 1.3266 - accuracy: 0.5306 - val_loss: 1.3786 - val_accuracy: 0.4821
# Epoch 44/150
# 117/117 - 31s - loss: 1.3134 - accuracy: 0.5411 - val_loss: 1.2981 - val_accuracy: 0.5112
# Epoch 45/150
# 117/117 - 30s - loss: 1.3075 - accuracy: 0.5470 - val_loss: 1.2904 - val_accuracy: 0.5290
# Epoch 46/150
# 117/117 - 35s - loss: 1.3212 - accuracy: 0.5256 - val_loss: 1.3528 - val_accuracy: 0.5067
# Epoch 47/150
# 117/117 - 31s - loss: 1.3038 - accuracy: 0.5425 - val_loss: 1.3022 - val_accuracy: 0.5469
# Epoch 48/150
# 117/117 - 33s - loss: 1.2945 - accuracy: 0.5377 - val_loss: 1.3666 - val_accuracy: 0.4955
# Epoch 49/150
# 117/117 - 32s - loss: 1.2888 - accuracy: 0.5427 - val_loss: 1.2751 - val_accuracy: 0.5446
# Epoch 50/150
# 117/117 - 32s - loss: 1.2934 - accuracy: 0.5473 - val_loss: 1.2953 - val_accuracy: 0.5112
# Epoch 51/150
# 117/117 - 31s - loss: 1.2637 - accuracy: 0.5494 - val_loss: 1.2349 - val_accuracy: 0.5379
# Epoch 52/150
# 117/117 - 37s - loss: 1.2759 - accuracy: 0.5435 - val_loss: 1.2681 - val_accuracy: 0.5469
# Epoch 53/150
# 117/117 - 37s - loss: 1.2693 - accuracy: 0.5430 - val_loss: 1.2794 - val_accuracy: 0.5513
# Epoch 54/150
# 117/117 - 41s - loss: 1.2848 - accuracy: 0.5384 - val_loss: 1.3056 - val_accuracy: 0.5179
# Epoch 55/150
# 117/117 - 35s - loss: 1.2497 - accuracy: 0.5580 - val_loss: 1.2623 - val_accuracy: 0.5335
# Epoch 56/150
# 117/117 - 39s - loss: 1.2647 - accuracy: 0.5481 - val_loss: 1.1835 - val_accuracy: 0.5670
# Epoch 57/150
# 117/117 - 38s - loss: 1.2657 - accuracy: 0.5513 - val_loss: 1.2641 - val_accuracy: 0.5067
# Epoch 58/150
# 117/117 - 39s - loss: 1.2329 - accuracy: 0.5602 - val_loss: 1.2346 - val_accuracy: 0.5379
# Epoch 59/150
# 117/117 - 36s - loss: 1.2454 - accuracy: 0.5513 - val_loss: 1.2333 - val_accuracy: 0.5603
# Epoch 60/150
# 117/117 - 34s - loss: 1.2463 - accuracy: 0.5596 - val_loss: 1.3319 - val_accuracy: 0.5179
# Epoch 61/150
# 117/117 - 40s - loss: 1.2410 - accuracy: 0.5621 - val_loss: 1.2626 - val_accuracy: 0.5357
# Epoch 62/150
# 117/117 - 32s - loss: 1.2299 - accuracy: 0.5548 - val_loss: 1.1839 - val_accuracy: 0.5826
# Epoch 63/150
# 117/117 - 38s - loss: 1.2525 - accuracy: 0.5516 - val_loss: 1.2926 - val_accuracy: 0.5424
# Epoch 64/150
# 117/117 - 34s - loss: 1.2569 - accuracy: 0.5537 - val_loss: 1.1949 - val_accuracy: 0.5714
# Epoch 65/150
# 117/117 - 32s - loss: 1.2279 - accuracy: 0.5558 - val_loss: 1.2763 - val_accuracy: 0.5246
# Epoch 66/150
# 117/117 - 34s - loss: 1.2204 - accuracy: 0.5661 - val_loss: 1.2758 - val_accuracy: 0.5335
# Epoch 67/150
# 117/117 - 34s - loss: 1.2106 - accuracy: 0.5696 - val_loss: 1.2602 - val_accuracy: 0.5513
# Epoch 68/150
# 117/117 - 32s - loss: 1.2229 - accuracy: 0.5580 - val_loss: 1.2401 - val_accuracy: 0.5290
# Epoch 69/150
# 117/117 - 30s - loss: 1.2313 - accuracy: 0.5507 - val_loss: 1.2787 - val_accuracy: 0.5335
# Epoch 70/150
# 117/117 - 29s - loss: 1.1968 - accuracy: 0.5666 - val_loss: 1.1738 - val_accuracy: 0.5848
# Epoch 71/150
# 117/117 - 32s - loss: 1.2253 - accuracy: 0.5591 - val_loss: 1.2285 - val_accuracy: 0.5536
# Epoch 72/150
# 117/117 - 33s - loss: 1.2044 - accuracy: 0.5684 - val_loss: 1.1351 - val_accuracy: 0.5759
# Epoch 73/150
# 117/117 - 32s - loss: 1.1722 - accuracy: 0.5847 - val_loss: 1.1549 - val_accuracy: 0.5848
# Epoch 74/150
# 117/117 - 32s - loss: 1.1760 - accuracy: 0.5761 - val_loss: 1.3218 - val_accuracy: 0.5067
# Epoch 75/150
# 117/117 - 32s - loss: 1.1924 - accuracy: 0.5692 - val_loss: 1.2092 - val_accuracy: 0.5513
# Epoch 76/150
# 117/117 - 31s - loss: 1.1737 - accuracy: 0.5767 - val_loss: 1.1876 - val_accuracy: 0.5871
# Epoch 77/150
# 117/117 - 32s - loss: 1.1839 - accuracy: 0.5764 - val_loss: 1.1773 - val_accuracy: 0.5714
# Epoch 78/150
# 117/117 - 32s - loss: 1.1758 - accuracy: 0.5739 - val_loss: 1.1743 - val_accuracy: 0.5781
# Epoch 79/150
# 117/117 - 32s - loss: 1.1813 - accuracy: 0.5779 - val_loss: 1.2598 - val_accuracy: 0.5223
# Epoch 80/150
# 117/117 - 31s - loss: 1.1871 - accuracy: 0.5780 - val_loss: 1.1487 - val_accuracy: 0.5491
# Epoch 81/150
# 117/117 - 32s - loss: 1.1791 - accuracy: 0.5673 - val_loss: 1.2110 - val_accuracy: 0.5558
# Epoch 82/150
# 117/117 - 32s - loss: 1.1707 - accuracy: 0.5712 - val_loss: 1.2083 - val_accuracy: 0.5536
# Epoch 83/150
# 117/117 - 32s - loss: 1.1575 - accuracy: 0.5791 - val_loss: 1.2733 - val_accuracy: 0.5424
# Epoch 84/150
# 117/117 - 32s - loss: 1.1928 - accuracy: 0.5696 - val_loss: 1.1401 - val_accuracy: 0.5848
# Epoch 85/150
# 117/117 - 31s - loss: 1.1489 - accuracy: 0.5905 - val_loss: 1.1952 - val_accuracy: 0.5558
# Epoch 86/150
# 117/117 - 31s - loss: 1.1654 - accuracy: 0.5699 - val_loss: 1.1715 - val_accuracy: 0.5469
# Epoch 87/150
# 117/117 - 32s - loss: 1.1681 - accuracy: 0.5761 - val_loss: 1.1531 - val_accuracy: 0.5737
# Epoch 88/150
# 117/117 - 31s - loss: 1.1565 - accuracy: 0.5841 - val_loss: 1.1769 - val_accuracy: 0.5893
# Epoch 89/150
# 117/117 - 31s - loss: 1.1510 - accuracy: 0.5921 - val_loss: 1.2034 - val_accuracy: 0.5603
# Epoch 90/150
# 117/117 - 33s - loss: 1.1523 - accuracy: 0.5745 - val_loss: 1.2354 - val_accuracy: 0.5491
# Epoch 91/150
# 117/117 - 34s - loss: 1.1547 - accuracy: 0.5838 - val_loss: 1.2043 - val_accuracy: 0.5558
# Epoch 92/150
# 117/117 - 32s - loss: 1.1365 - accuracy: 0.5844 - val_loss: 1.1805 - val_accuracy: 0.5692
# Epoch 93/150
# 117/117 - 33s - loss: 1.1633 - accuracy: 0.5857 - val_loss: 1.1722 - val_accuracy: 0.5759
# Epoch 94/150
# 117/117 - 36s - loss: 1.1484 - accuracy: 0.5862 - val_loss: 1.2453 - val_accuracy: 0.5156
# Epoch 95/150
# 117/117 - 39s - loss: 1.1253 - accuracy: 0.5943 - val_loss: 1.1462 - val_accuracy: 0.5647
# Epoch 96/150
# 117/117 - 31s - loss: 1.1483 - accuracy: 0.5854 - val_loss: 1.1506 - val_accuracy: 0.5871
# Epoch 97/150
# 117/117 - 30s - loss: 1.1286 - accuracy: 0.5889 - val_loss: 1.1842 - val_accuracy: 0.5469
# Epoch 98/150
# 117/117 - 31s - loss: 1.1360 - accuracy: 0.5892 - val_loss: 1.1335 - val_accuracy: 0.6027
# Epoch 99/150
# 117/117 - 32s - loss: 1.1298 - accuracy: 0.5922 - val_loss: 1.1514 - val_accuracy: 0.5670
# Epoch 100/150
# 117/117 - 32s - loss: 1.1327 - accuracy: 0.5873 - val_loss: 1.1443 - val_accuracy: 0.5737
# Epoch 101/150
# 117/117 - 32s - loss: 1.1097 - accuracy: 0.5954 - val_loss: 1.1726 - val_accuracy: 0.5670
# Epoch 102/150
# 117/117 - 31s - loss: 1.1239 - accuracy: 0.5927 - val_loss: 1.1705 - val_accuracy: 0.5670
# Epoch 103/150
# 117/117 - 32s - loss: 1.1251 - accuracy: 0.5881 - val_loss: 1.1601 - val_accuracy: 0.5580
# Epoch 104/150
# 117/117 - 31s - loss: 1.1059 - accuracy: 0.6029 - val_loss: 1.1112 - val_accuracy: 0.5714
# Epoch 105/150
# 117/117 - 34s - loss: 1.1239 - accuracy: 0.5852 - val_loss: 1.1621 - val_accuracy: 0.5848
# Epoch 106/150
# 117/117 - 34s - loss: 1.0909 - accuracy: 0.6076 - val_loss: 1.0818 - val_accuracy: 0.5982
# Epoch 107/150
# 117/117 - 34s - loss: 1.1128 - accuracy: 0.5892 - val_loss: 1.1532 - val_accuracy: 0.5714
# Epoch 108/150
# 117/117 - 38s - loss: 1.0947 - accuracy: 0.5913 - val_loss: 1.1941 - val_accuracy: 0.5759
# Epoch 109/150
# 117/117 - 33s - loss: 1.1147 - accuracy: 0.5946 - val_loss: 1.1004 - val_accuracy: 0.6027
# Epoch 110/150
# 117/117 - 38s - loss: 1.0869 - accuracy: 0.6055 - val_loss: 1.1671 - val_accuracy: 0.5625
# Epoch 111/150
# 117/117 - 31s - loss: 1.0763 - accuracy: 0.6104 - val_loss: 1.1371 - val_accuracy: 0.5603
# Epoch 112/150
# 117/117 - 30s - loss: 1.0721 - accuracy: 0.6098 - val_loss: 1.0934 - val_accuracy: 0.5982
# Epoch 113/150
# 117/117 - 30s - loss: 1.0824 - accuracy: 0.6079 - val_loss: 1.1712 - val_accuracy: 0.5714
# Epoch 114/150
# 117/117 - 30s - loss: 1.0977 - accuracy: 0.5983 - val_loss: 1.1172 - val_accuracy: 0.5938
# Epoch 115/150
# 117/117 - 31s - loss: 1.1101 - accuracy: 0.6042 - val_loss: 1.1200 - val_accuracy: 0.5737
# Epoch 116/150
# 117/117 - 30s - loss: 1.0874 - accuracy: 0.6112 - val_loss: 1.2044 - val_accuracy: 0.5625
# Epoch 117/150
# 117/117 - 32s - loss: 1.1064 - accuracy: 0.5986 - val_loss: 1.1512 - val_accuracy: 0.5424
# Epoch 118/150
# 117/117 - 33s - loss: 1.0801 - accuracy: 0.5935 - val_loss: 1.2591 - val_accuracy: 0.5625
# Epoch 119/150
# 117/117 - 32s - loss: 1.0491 - accuracy: 0.6146 - val_loss: 1.1162 - val_accuracy: 0.5781
# Epoch 120/150
# 117/117 - 36s - loss: 1.0750 - accuracy: 0.6047 - val_loss: 1.1855 - val_accuracy: 0.5804
# Epoch 121/150
# 117/117 - 32s - loss: 1.0637 - accuracy: 0.6084 - val_loss: 1.1316 - val_accuracy: 0.5938
# Epoch 122/150
# 117/117 - 30s - loss: 1.0552 - accuracy: 0.6150 - val_loss: 1.1539 - val_accuracy: 0.5670
# Epoch 123/150
# 117/117 - 31s - loss: 1.0500 - accuracy: 0.6157 - val_loss: 1.1301 - val_accuracy: 0.5647
# Epoch 124/150
# 117/117 - 31s - loss: 1.0630 - accuracy: 0.6140 - val_loss: 1.0860 - val_accuracy: 0.5915
# Epoch 125/150
# 117/117 - 30s - loss: 1.0734 - accuracy: 0.6037 - val_loss: 1.2180 - val_accuracy: 0.5357
# Epoch 126/150
# 117/117 - 30s - loss: 1.0440 - accuracy: 0.6147 - val_loss: 1.1252 - val_accuracy: 0.5848
# Epoch 127/150
# 117/117 - 29s - loss: 1.0457 - accuracy: 0.6234 - val_loss: 1.1386 - val_accuracy: 0.5670
# Epoch 128/150
# 117/117 - 30s - loss: 1.0705 - accuracy: 0.6080 - val_loss: 1.1599 - val_accuracy: 0.5558
# Epoch 129/150
# 117/117 - 30s - loss: 1.0508 - accuracy: 0.6163 - val_loss: 1.1236 - val_accuracy: 0.5938
# Epoch 130/150
# 117/117 - 30s - loss: 1.0321 - accuracy: 0.6206 - val_loss: 1.1760 - val_accuracy: 0.5536
# Epoch 131/150
# 117/117 - 30s - loss: 1.0579 - accuracy: 0.6174 - val_loss: 1.0494 - val_accuracy: 0.6004
# Epoch 132/150
# 117/117 - 30s - loss: 1.0299 - accuracy: 0.6244 - val_loss: 1.1514 - val_accuracy: 0.5915
# Epoch 133/150
# 117/117 - 30s - loss: 1.0387 - accuracy: 0.6253 - val_loss: 1.1155 - val_accuracy: 0.5737
# Epoch 134/150
# 117/117 - 30s - loss: 1.0491 - accuracy: 0.6128 - val_loss: 1.1053 - val_accuracy: 0.5759
# Epoch 135/150
# 117/117 - 32s - loss: 1.0430 - accuracy: 0.6260 - val_loss: 1.1509 - val_accuracy: 0.5603
# Epoch 136/150
# 117/117 - 32s - loss: 1.0350 - accuracy: 0.6223 - val_loss: 1.0264 - val_accuracy: 0.6272
# Epoch 137/150
# 117/117 - 30s - loss: 1.0314 - accuracy: 0.6197 - val_loss: 1.2391 - val_accuracy: 0.5290
# Epoch 138/150
# 117/117 - 30s - loss: 1.0293 - accuracy: 0.6234 - val_loss: 1.0786 - val_accuracy: 0.6228
# Epoch 139/150
# 117/117 - 30s - loss: 1.0443 - accuracy: 0.6169 - val_loss: 1.0503 - val_accuracy: 0.6362
# Epoch 140/150
# 117/117 - 30s - loss: 1.0205 - accuracy: 0.6338 - val_loss: 1.1443 - val_accuracy: 0.5982
# Epoch 141/150
# 117/117 - 30s - loss: 1.0409 - accuracy: 0.6194 - val_loss: 1.1916 - val_accuracy: 0.5290
# Epoch 142/150
# 117/117 - 29s - loss: 1.0303 - accuracy: 0.6204 - val_loss: 1.1420 - val_accuracy: 0.5759
# Epoch 143/150
# 117/117 - 30s - loss: 1.0044 - accuracy: 0.6359 - val_loss: 1.0785 - val_accuracy: 0.6027
# Epoch 144/150
# 117/117 - 30s - loss: 1.0189 - accuracy: 0.6185 - val_loss: 1.0908 - val_accuracy: 0.5781
# Epoch 145/150
# 117/117 - 31s - loss: 1.0300 - accuracy: 0.6179 - val_loss: 1.0628 - val_accuracy: 0.6205
# Epoch 146/150
# 117/117 - 33s - loss: 1.0329 - accuracy: 0.6143 - val_loss: 1.0602 - val_accuracy: 0.6183
# Epoch 147/150
# 117/117 - 31s - loss: 1.0154 - accuracy: 0.6247 - val_loss: 1.0926 - val_accuracy: 0.5759
# Epoch 148/150
# 117/117 - 31s - loss: 0.9988 - accuracy: 0.6250 - val_loss: 1.1665 - val_accuracy: 0.5737
# Epoch 149/150
# 117/117 - 31s - loss: 1.0122 - accuracy: 0.6210 - val_loss: 1.0940 - val_accuracy: 0.6071
# Epoch 150/150
# 117/117 - 31s - loss: 1.0003 - accuracy: 0.6300 - val_loss: 1.0710 - val_accuracy: 0.6205

# %%
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs    = range(1,len(acc)+1,1) # obtener número de epochs del eje X

plt.plot  ( epochs,     acc, 'r--', label='Training acc'  )
plt.plot  ( epochs, val_acc,  'b', label='Validation acc')
plt.title ('Training and Validation Accuracy')
plt.ylabel('acc')
plt.xlabel('epochs')

plt.legend()
plt.figure()


plt.plot  ( epochs,     loss, 'r--' )
plt.plot  ( epochs, val_loss ,  'b' )
plt.title ('Training and Validation Loss'   )
plt.ylabel('loss')
plt.xlabel('epochs')

plt.legend()
plt.figure()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
test_lost, test_acc= model.evaluate(test_generator)
print ("Test Accuracy:", test_acc)
# Out:
# 30/30 [==============================] - 6s 210ms/step - loss: 1.1050 - accuracy: 0.5889
# Test Accuracy: 0.5889244079589844

# %%
# Save the model
model.save('Contador_de_hojas_vfinal.h5')

# %%
# Confusion Matrix
Y_pred = model.predict(test_generator, len(test_dir) // (32+1))
y_pred = np.argmax(Y_pred, axis=1)
target_names = ['1', '2','3','4','5','6','7','8','9+']
print('Confusion Matrix')
cm = confusion_matrix(test_generator.classes, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=target_names)
disp.plot(cmap=plt.cm.Blues)
plt.show()
print('Classification Report')
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# Confusion Matrix
# Classification Report
#               precision    recall  f1-score   support
#
#            1       0.13      0.11      0.12        92
#            2       0.34      0.36      0.35       329
#            3       0.03      0.01      0.02        94
#            4       0.21      0.38      0.27       208
#            5       0.00      0.00      0.00        60
#            6       0.00      0.00      0.00        65
#            7       0.00      0.00      0.00        18
#            8       0.00      0.00      0.00        16
#           9+       0.07      0.11      0.08        57
#
#     accuracy                           0.23       939
#    macro avg       0.09      0.11      0.09       939
# weighted avg       0.19      0.23      0.20       939
