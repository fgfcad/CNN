# %%
# imports
import cv2 as cv
import numpy as np
import os

# %%
green = np.uint8([[[0,255,0 ]]])
hsv_green = cv.cvtColor(green,cv.COLOR_BGR2HSV)
print( hsv_green )
# Out:
# [[[ 60 255 255]]]

# %%
img = cv.imread('hojas/2/7.png')

# Convert BGR to HSV
hsv = cv.cvtColor(img,cv.COLOR_BGR2HSV)
# Selección de los colores
lower_green = np.array([30,25,25])
upper_green = np.array([85,255,255])
# Threshold
mask = cv.inRange(hsv, lower_green, upper_green)
# Bitwise-AND mask and original image
res = cv.bitwise_and(img,img, mask= mask)

kernel = np.ones((5,5),np.uint8)
erosion = cv.erode(res,kernel,iterations = 3)

cv.imshow('original',img)
cv.imshow('bw',mask)
cv.imshow('res',res)
cv.imshow('erosion',erosion)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
# Ruta de las imágenes
hoja1 = r'hojas/1'
hoja2 = r'hojas/2'
hoja3 = r'hojas/3'
hoja4 = r'hojas/4'
hoja5 = r'hojas/5'
hoja6 = r'hojas/6'
hoja7 = r'hojas/7'
hoja8 = r'hojas/8'
hoja9 = "hojas/9+"

# Bucle para las imágenes de 1 hoja
i=0
while len(os.listdir('hojas/1_mod') ) < 617:
    if os.path.isfile('hojas/1/'+str(i)+'.png'):
        img = cv.imread(hoja1 + '/' + str(i) + '.png')
        hsv = cv.cvtColor(img,cv.COLOR_BGR2HSV)
        # Selección de los colores
        lower_green = np.array([30,25,25])
        upper_green = np.array([85,255,255])
        # Threshold
        mask = cv.inRange(hsv, lower_green, upper_green)
        # Bitwise-AND mask and original image
        res = cv.bitwise_and(img,img, mask= mask)
        # Guardar imagen
        cv.imwrite('hojas/1_mod/' + str(i) + '.png', res) 
        i+=1
    else:
        i+=1
# Bucle para las imágenes de 2 hojas
i=0
while len(os.listdir('hojas/2_mod') ) < 617:
    if os.path.isfile('hojas/2/'+str(i)+'.png'):
        img = cv.imread(hoja2 + '/' + str(i) + '.png')
        hsv = cv.cvtColor(img,cv.COLOR_BGR2HSV)
        # Selección de los colores
        lower_green = np.array([30,25,25])
        upper_green = np.array([85,255,255])
        # Threshold
        mask = cv.inRange(hsv, lower_green, upper_green)
        # Bitwise-AND mask and original image
        res = cv.bitwise_and(img,img, mask= mask)
        # Erosion
        kernel = np.ones((5,5),np.uint8)
        erosion = cv.erode(res,kernel,iterations = 1)
        # Guardar imagen
        cv.imwrite('hojas/2_mod/' + str(i) + '.png', erosion) 
        i+=1
    else:
        i+=1
# Bucle para las imágenes de 3 hojas
i=0
while len(os.listdir('hojas/3_mod') ) < 615:
    if os.path.isfile('hojas/3/'+str(i)+'.png'):
        img = cv.imread(hoja3 + '/' + str(i) + '.png')
        hsv = cv.cvtColor(img,cv.COLOR_BGR2HSV)
        # Selección de los colores
        lower_green = np.array([30,25,25])
        upper_green = np.array([85,255,255])
        # Threshold
        mask = cv.inRange(hsv, lower_green, upper_green)
        # Bitwise-AND mask and original image
        res = cv.bitwise_and(img,img, mask= mask)
        # Erosion
        kernel = np.ones((5,5),np.uint8)
        erosion = cv.erode(res,kernel,iterations = 1)
        # Guardar imagen
        cv.imwrite('hojas/3_mod/' + str(i) + '.png', erosion)
        i+=1
    else:
        i+=1
# Bucle para las imágenes de 4 hojas
i=0
while len(os.listdir('hojas/4_mod') ) < 786:
    if os.path.isfile('hojas/4/'+str(i)+'.png'):
        img = cv.imread(hoja4 + '/' + str(i) + '.png')
        hsv = cv.cvtColor(img,cv.COLOR_BGR2HSV)
        # Selección de los colores
        lower_green = np.array([30,25,25])
        upper_green = np.array([85,255,255])
        # Threshold
        mask = cv.inRange(hsv, lower_green, upper_green)
        # Bitwise-AND mask and original image
        res = cv.bitwise_and(img,img, mask= mask)
        # Erosion
        kernel = np.ones((5,5),np.uint8)
        erosion = cv.erode(res,kernel,iterations = 1)
        # Guardar imagen
        cv.imwrite('hojas/4_mod/' + str(i) + '.png', erosion)
        i+=1
    else:
        i+=1
# Bucle para las imágenes de 5 hojas
i=0
while len(os.listdir('hojas/5_mod') ) < len(os.listdir('hojas/5')):
    if os.path.isfile('hojas/5/'+str(i)+'.png'):
        img = cv.imread(hoja5 + '/' + str(i) + '.png')
        hsv = cv.cvtColor(img,cv.COLOR_BGR2HSV)
        # Selección de los colores
        lower_green = np.array([30,25,25])
        upper_green = np.array([85,255,255])
        # Threshold
        mask = cv.inRange(hsv, lower_green, upper_green)
        # Bitwise-AND mask and original image
        res = cv.bitwise_and(img,img, mask= mask)
        # Erosion
        kernel = np.ones((5,5),np.uint8)
        erosion = cv.erode(res,kernel,iterations = 1)
        # Guardar imagen
        cv.imwrite('hojas/5_mod/' + str(i) + '.png', erosion)
        i+=1
    else:
        i+=1
# Bucle para las imágenes de 6 hojas
i=0
while len(os.listdir('hojas/6_mod') ) < len(os.listdir('hojas/6')):
    if os.path.isfile('hojas/6/'+str(i)+'.png'):
        img = cv.imread(hoja6 + '/' + str(i) + '.png')
        hsv = cv.cvtColor(img,cv.COLOR_BGR2HSV)
        # Selección de los colores
        lower_green = np.array([30,25,25])
        upper_green = np.array([85,255,255])
        # Threshold
        mask = cv.inRange(hsv, lower_green, upper_green)
        # Bitwise-AND mask and original image
        res = cv.bitwise_and(img,img, mask= mask)
        # Erosion
        kernel = np.ones((5,5),np.uint8)
        erosion = cv.erode(res,kernel,iterations = 1)
        # Guardar imagen
        cv.imwrite('hojas/6_mod/' + str(i) + '.png', erosion)
        i+=1
    else:
        i+=1
# Bucle para las imágenes de 7 hojas
i=0
while len(os.listdir('hojas/7_mod') ) < len(os.listdir('hojas/7')):
    if os.path.isfile('hojas/7/'+str(i)+'.png'):
        img = cv.imread(hoja7 + '/' + str(i) + '.png')
        hsv = cv.cvtColor(img,cv.COLOR_BGR2HSV)
        # Selección de los colores
        lower_green = np.array([30,25,25])
        upper_green = np.array([85,255,255])
        # Threshold
        mask = cv.inRange(hsv, lower_green, upper_green)
        # Bitwise-AND mask and original image
        res = cv.bitwise_and(img,img, mask= mask)
        # Erosion
        kernel = np.ones((5,5),np.uint8)
        erosion = cv.erode(res,kernel,iterations = 1)
        # Guardar imagen
        cv.imwrite('hojas/7_mod/' + str(i) + '.png', erosion)
        i+=1
    else:
        i+=1
# Bucle para las imágenes de 8 hojas
i=0
while len(os.listdir('hojas/8_mod') ) < len(os.listdir('hojas/8')):
    if os.path.isfile('hojas/8/'+str(i)+'.png'):
        img = cv.imread(hoja8 + '/' + str(i) + '.png')
        hsv = cv.cvtColor(img,cv.COLOR_BGR2HSV)
        # Selección de los colores
        lower_green = np.array([30,25,25])
        upper_green = np.array([85,255,255])
        # Threshold
        mask = cv.inRange(hsv, lower_green, upper_green)
        # Bitwise-AND mask and original image
        res = cv.bitwise_and(img,img, mask= mask)
        # Erosion
        kernel = np.ones((5,5),np.uint8)
        erosion = cv.erode(res,kernel,iterations = 1)
        # Guardar imagen
        cv.imwrite('hojas/8_mod/' + str(i) + '.png', erosion)
        i+=1
    else:
        i+=1
# Bucle para las imágenes de 9 hojas
i=0
while len(os.listdir('hojas/9+_mod') ) < len(os.listdir('hojas/9+')):
    if os.path.isfile('hojas/9+/'+str(i)+'.png'):
        img = cv.imread(hoja9 + '/' + str(i) + '.png')
        hsv = cv.cvtColor(img,cv.COLOR_BGR2HSV)
        # Selección de los colores
        lower_green = np.array([30,25,25])
        upper_green = np.array([85,255,255])
        # Threshold
        mask = cv.inRange(hsv, lower_green, upper_green)
        # Bitwise-AND mask and original image
        res = cv.bitwise_and(img,img, mask= mask)
        # Erosion
        kernel = np.ones((5,5),np.uint8)
        erosion = cv.erode(res,kernel,iterations = 1)
        # Guardar imagen
        cv.imwrite('hojas/9+_mod/' + str(i) + '.png', erosion)
        i+=1
    else:
        i+=1
# Out:
# "\n# Bucle para las imágenes de más de 7 hojas\ni=0\nwhile len(os.listdir('hojas/7+_mod') ) < 676:\n    if os.path.isfile('hojas/7+/'+str(i)+'.png'):\n        img = cv.imread(hoja7plus + '/' + str(i) + '.png')\n        hsv = cv.cvtColor(img,cv.COLOR_BGR2HSV)\n        # Selección de los colores\n        lower_green = np.array([30,25,25])\n        upper_green = np.array([85,255,255])\n        # Threshold\n        mask = cv.inRange(hsv, lower_green, upper_green)\n        # Bitwise-AND mask and original image\n        res = cv.bitwise_and(img,img, mask= mask)\n        # Erosion\n        kernel = np.ones((5,5),np.uint8)\n        erosion = cv.erode(res,kernel,iterations = 1)\n        # Guardar imagen\n        cv.imwrite('hojas/7+_mod/' + str(i) + '.png', erosion)\n        i+=1\n    else:\n        i+=1\n"

# %%
hoja2 = r'hojas/2'
i=0
while len(os.listdir("C:/Users/ferga/Documents/MATLAB/TFG/2_mod") ) < 617:
    if os.path.isfile('hojas/2/'+str(i)+'.png'):
        img = cv.imread(hoja2 + '/' + str(i) + '.png')
        hsv = cv.cvtColor(img,cv.COLOR_BGR2HSV)
        # Selección de los colores
        lower_green = np.array([30,25,25])
        upper_green = np.array([85,255,255])
        # Threshold
        mask = cv.inRange(hsv, lower_green, upper_green)
        # Bitwise-AND mask and original image
        res = cv.bitwise_and(img,img, mask= mask)
        # Erosion
        kernel = np.ones((5,5),np.uint8)
        erosion = cv.erode(res,kernel,iterations = 3)
        # Guardar imagen
        cv.imwrite('C:/Users/ferga/Documents/MATLAB/TFG/2_mod/' + str(i) + '.png', erosion) 
        i+=1
    else:
        i+=1
